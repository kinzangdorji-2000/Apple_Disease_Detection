# %% [markdown]
# # Apple Detection

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras import  models,layers
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
#constant for the training processes
image_size = 224
channels = 3
epochs = 50
batch_size=16

# %% [markdown]
# ## Loading Dataset

# %%
training_data = ImageDataGenerator(
    rescale = 1.0/255,
    horizontal_flip=True,
    rotation_range = 10
)

train_gen = training_data.flow_from_directory(
    'Final_Dataset/train',
    target_size = (image_size,image_size),
    batch_size = 16,
    class_mode = 'sparse'
)
# Out:
# Found 2526 images belonging to 3 classes.

# %%
val_data = ImageDataGenerator(
    rescale = 1.0 / 255,
    horizontal_flip= True,
    rotation_range= 10,
)

val_gen = val_data.flow_from_directory(
    'Final_Dataset/val',
    target_size=(image_size,image_size),
    batch_size=16,
    class_mode='sparse'
)
# Out:
# Found 315 images belonging to 3 classes.

# %%
test_data = ImageDataGenerator(
    rescale=1.0/255,
    horizontal_flip=True,
    rotation_range=10

)
test_gen = test_data.flow_from_directory(
    'Final_Dataset/test',
    target_size=(image_size, image_size),
    batch_size = 16,
    class_mode='sparse'
)
# Out:
# Found 318 images belonging to 3 classes.

# %%
print(train_gen.class_indices)
# Out:
# {'Bad_Apple': 0, 'Non_Apple': 1, 'Normal_Apple': 2}

# %%
class_names = list(train_gen.class_indices.keys())
class_names
# Out:
# ['Bad_Apple', 'Non_Apple', 'Normal_Apple']

# %%
plt.figure(figsize=(10, 10))
for image_batch, label_batch in train_gen:
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(image_batch[i])
        plt.title(class_names[int(label_batch[i])])
        plt.axis("off")

# %% [markdown]
# ## Model Building

# %%
input_shape = (image_size,image_size,channels)
class_labels = 3

model = models.Sequential([
    
    layers.InputLayer(input_shape = input_shape),
    # first layers of cnn
    layers.Conv2D(32,(3,3), activation = 'relu', input_shape = input_shape),
    layers.MaxPooling2D((2,2)),
    # second layers of cnn
    layers.Conv2D(64, kernel_size = (3,3), activation = 'relu'),
    layers.MaxPooling2D((2,2)),
    
    # third layers of cnn
    layers.Conv2D(64,(3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),
    
    #fouth layers of cnn
    layers.Conv2D(64,(3,3),activation='relu'),
    layers.MaxPooling2D((2,2)),
    
    #flatten layers
    layers.Flatten(),
    
    #dense layers
    layers.Dense(64, activation= 'relu'),
    
    #out put layers
    layers.Dense(class_labels, activation='softmax'),
    
])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 222, 222, 32)      896
#
#  max_pooling2d_8 (MaxPooling  (None, 111, 111, 32)     0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_9 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 52, 52, 64)        36928
#
#  max_pooling2d_10 (MaxPoolin  (None, 26, 26, 64)       0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 24, 24, 64)        36928
#
#  max_pooling2d_11 (MaxPoolin  (None, 12, 12, 64)       0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 9216)              0
#
#  dense_4 (Dense)             (None, 64)                589888
#
#  dense_5 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 683,331
# Trainable params: 683,331
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compile the model

# %%
#hyperparameters
model.compile(
    optimizer='adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %% [markdown]
# ## Train the model

# %%
history = model.fit(    
    train_gen,
    batch_size=16,
    validation_data=val_gen,
    verbose = 1,
    epochs = 50
)
# Out:
# Epoch 1/50
# 158/158 [==============================] - 172s 1s/step - loss: 0.4560 - accuracy: 0.7922 - val_loss: 0.3325 - val_accuracy: 0.8571
# Epoch 2/50
# 158/158 [==============================] - 175s 1s/step - loss: 0.1838 - accuracy: 0.9422 - val_loss: 0.1088 - val_accuracy: 0.9714
# Epoch 3/50
# 158/158 [==============================] - 173s 1s/step - loss: 0.1385 - accuracy: 0.9600 - val_loss: 0.3646 - val_accuracy: 0.8889
# Epoch 4/50
# 158/158 [==============================] - 167s 1s/step - loss: 0.1014 - accuracy: 0.9723 - val_loss: 0.1551 - val_accuracy: 0.9175
# Epoch 5/50
# 158/158 [==============================] - 168s 1s/step - loss: 0.0403 - accuracy: 0.9869 - val_loss: 0.0302 - val_accuracy: 0.9905
# Epoch 6/50
# 158/158 [==============================] - 166s 1s/step - loss: 0.0417 - accuracy: 0.9877 - val_loss: 0.0149 - val_accuracy: 0.9968
# Epoch 7/50
# 158/158 [==============================] - 166s 1s/step - loss: 0.0543 - accuracy: 0.9850 - val_loss: 0.0506 - val_accuracy: 0.9810
# Epoch 8/50
# 158/158 [==============================] - 166s 1s/step - loss: 0.0246 - accuracy: 0.9905 - val_loss: 0.0435 - val_accuracy: 0.9810
# Epoch 9/50
# 158/158 [==============================] - 166s 1s/step - loss: 0.0307 - accuracy: 0.9917 - val_loss: 0.0107 - val_accuracy: 0.9968
# Epoch 10/50
# 158/158 [==============================] - 170s 1s/step - loss: 0.0072 - accuracy: 0.9980 - val_loss: 0.0078 - val_accuracy: 0.9968
# Epoch 11/50
# 158/158 [==============================] - 158s 998ms/step - loss: 0.0037 - accuracy: 0.9992 - val_loss: 0.0094 - val_accuracy: 0.9968
# Epoch 12/50
# 158/158 [==============================] - 97s 613ms/step - loss: 0.0048 - accuracy: 0.9988 - val_loss: 0.0139 - val_accuracy: 0.9937
# Epoch 13/50
# 158/158 [==============================] - 96s 610ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.0094 - val_accuracy: 0.9968
# Epoch 14/50
# 158/158 [==============================] - 100s 635ms/step - loss: 0.0259 - accuracy: 0.9917 - val_loss: 0.0371 - val_accuracy: 0.9905
# Epoch 15/50
# 158/158 [==============================] - 98s 617ms/step - loss: 0.0491 - accuracy: 0.9834 - val_loss: 0.0084 - val_accuracy: 0.9968
# Epoch 16/50
# 158/158 [==============================] - 98s 621ms/step - loss: 0.0294 - accuracy: 0.9925 - val_loss: 0.0209 - val_accuracy: 0.9937
# Epoch 17/50
# 158/158 [==============================] - 99s 629ms/step - loss: 0.0061 - accuracy: 0.9980 - val_loss: 0.0155 - val_accuracy: 0.9968
# Epoch 18/50
# 158/158 [==============================] - 109s 691ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0180 - val_accuracy: 0.9968
# Epoch 19/50
# 158/158 [==============================] - 111s 704ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.0174 - val_accuracy: 0.9968
# Epoch 20/50
# 158/158 [==============================] - 103s 651ms/step - loss: 0.0040 - accuracy: 0.9988 - val_loss: 0.0175 - val_accuracy: 0.9968
# Epoch 21/50
# 158/158 [==============================] - 110s 695ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0179 - val_accuracy: 0.9937
# Epoch 22/50
# 158/158 [==============================] - 100s 632ms/step - loss: 0.0518 - accuracy: 0.9826 - val_loss: 0.0078 - val_accuracy: 0.9968
# Epoch 23/50
# 158/158 [==============================] - 101s 636ms/step - loss: 0.0070 - accuracy: 0.9972 - val_loss: 0.0194 - val_accuracy: 0.9937
# Epoch 24/50
# 158/158 [==============================] - 108s 683ms/step - loss: 0.0367 - accuracy: 0.9905 - val_loss: 0.0149 - val_accuracy: 0.9937
# Epoch 25/50
# 158/158 [==============================] - 113s 716ms/step - loss: 0.0066 - accuracy: 0.9980 - val_loss: 0.0325 - val_accuracy: 0.9937
# Epoch 26/50
# 158/158 [==============================] - 108s 681ms/step - loss: 0.0054 - accuracy: 0.9984 - val_loss: 0.0163 - val_accuracy: 0.9968
# Epoch 27/50
# 158/158 [==============================] - 103s 649ms/step - loss: 0.0043 - accuracy: 0.9980 - val_loss: 0.0458 - val_accuracy: 0.9905
# Epoch 28/50
# 158/158 [==============================] - 110s 698ms/step - loss: 0.0135 - accuracy: 0.9945 - val_loss: 0.0067 - val_accuracy: 0.9937
# Epoch 29/50
# 158/158 [==============================] - 104s 657ms/step - loss: 0.0383 - accuracy: 0.9909 - val_loss: 0.0361 - val_accuracy: 0.9968
# Epoch 30/50
# 158/158 [==============================] - 100s 632ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.0160 - val_accuracy: 0.9968
# Epoch 31/50
# 158/158 [==============================] - 101s 640ms/step - loss: 8.3895e-04 - accuracy: 1.0000 - val_loss: 0.0186 - val_accuracy: 0.9968
# Epoch 32/50
# 158/158 [==============================] - 103s 651ms/step - loss: 0.0088 - accuracy: 0.9968 - val_loss: 0.0223 - val_accuracy: 0.9937
# Epoch 33/50
# 158/158 [==============================] - 116s 734ms/step - loss: 4.6371e-04 - accuracy: 1.0000 - val_loss: 0.0190 - val_accuracy: 0.9968
# Epoch 34/50
# 158/158 [==============================] - 108s 683ms/step - loss: 1.7005e-04 - accuracy: 1.0000 - val_loss: 0.0311 - val_accuracy: 0.9968
# Epoch 35/50
# 158/158 [==============================] - 104s 655ms/step - loss: 3.5040e-04 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 0.9968
# Epoch 36/50
# 158/158 [==============================] - 116s 735ms/step - loss: 0.0135 - accuracy: 0.9968 - val_loss: 0.0588 - val_accuracy: 0.9841
# Epoch 37/50
# 158/158 [==============================] - 115s 728ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.0411 - val_accuracy: 0.9968
# Epoch 38/50
# 158/158 [==============================] - 111s 702ms/step - loss: 2.0340e-04 - accuracy: 1.0000 - val_loss: 0.0179 - val_accuracy: 0.9968
# Epoch 39/50
# 158/158 [==============================] - 116s 734ms/step - loss: 0.0665 - accuracy: 0.9826 - val_loss: 0.0337 - val_accuracy: 0.9937
# Epoch 40/50
# 158/158 [==============================] - 115s 724ms/step - loss: 0.0046 - accuracy: 0.9988 - val_loss: 0.0229 - val_accuracy: 0.9968
# Epoch 41/50
# 158/158 [==============================] - 118s 748ms/step - loss: 0.0020 - accuracy: 0.9988 - val_loss: 0.0307 - val_accuracy: 0.9968
# Epoch 42/50
# 158/158 [==============================] - 116s 730ms/step - loss: 3.0988e-04 - accuracy: 1.0000 - val_loss: 0.0307 - val_accuracy: 0.9968
# Epoch 43/50
# 158/158 [==============================] - 116s 731ms/step - loss: 1.3681e-04 - accuracy: 1.0000 - val_loss: 0.0220 - val_accuracy: 0.9968
# Epoch 44/50
# 158/158 [==============================] - 105s 662ms/step - loss: 0.0019 - accuracy: 0.9992 - val_loss: 0.0359 - val_accuracy: 0.9968
# Epoch 45/50
# 158/158 [==============================] - 104s 660ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0280 - val_accuracy: 0.9968
# Epoch 46/50
# 158/158 [==============================] - 104s 659ms/step - loss: 0.0085 - accuracy: 0.9960 - val_loss: 0.0133 - val_accuracy: 0.9937
# Epoch 47/50
# 158/158 [==============================] - 107s 679ms/step - loss: 4.3995e-04 - accuracy: 1.0000 - val_loss: 0.0284 - val_accuracy: 0.9937
# Epoch 48/50
# 158/158 [==============================] - 106s 667ms/step - loss: 1.4304e-04 - accuracy: 1.0000 - val_loss: 0.0169 - val_accuracy: 0.9968
# Epoch 49/50
# 158/158 [==============================] - 99s 627ms/step - loss: 2.1465e-04 - accuracy: 1.0000 - val_loss: 0.0162 - val_accuracy: 0.9968
# Epoch 50/50
# 158/158 [==============================] - 95s 601ms/step - loss: 7.5844e-05 - accuracy: 1.0000 - val_loss: 0.0352 - val_accuracy: 0.9968

# %% [markdown]
# ## Model Evaluation

# %%
#train accuracy
score = model.evaluate(train_gen)
# Out:
# 158/158 [==============================] - 39s 248ms/step - loss: 9.5575e-05 - accuracy: 1.0000

# %%
#test accuracy
score = model.evaluate(test_gen)
# Out:
# 20/20 [==============================] - 8s 375ms/step - loss: 0.0420 - accuracy: 0.9937

# %%
#parameters used for training model
history.params
# Out:
# {'verbose': 1, 'epochs': 50, 'steps': 158}

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# ## Visualizing Accuracy and Loss Curves

# %%
train_loss = history.history['loss']
train_acc = history.history['accuracy']

val_loss = history.history['val_loss']
val_acc = history.history['val_accuracy']

# %%
epochs = 50
plt.figure(figsize= (8,8))
plt.subplot(1,2,1)
plt.plot(range(epochs),train_acc, label = 'Training Accuracy')
plt.plot(range(epochs),val_acc, label = 'Validation Accuracy')
plt.legend(loc = 'lower right')
plt.title('Training vs Validation accuracy')

plt.subplot(1,2,2)
plt.plot(range(epochs),train_loss, label = 'Loss')
plt.plot(range(epochs),val_loss,label = 'Validation loss')
plt.title('Loss vs Validation loss')
# Out:
# Text(0.5, 1.0, 'Loss vs Validation loss')

# %% [markdown]
# ## Prediction on a sample image

# %%
import numpy as np

for image_batch, label_batch in test_gen:
    first_image = image_batch[0]
    first_label = int(label_batch[0])
    
    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])
    
    batch_prediction = model.predict(image_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
    plt.axis('off')
    
    break
# Out:
# first image to predict
# actual label: Non_Apple
# predicted label: Normal_Apple

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i])
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_gen:
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i])
        
        predicted_class, confidence = predict(model, images[i])
        actual_class = class_names[int(labels[i])] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")
    break

# %% [markdown]
# ## Saving Model

# %%
model.save('apple_model.h5')
